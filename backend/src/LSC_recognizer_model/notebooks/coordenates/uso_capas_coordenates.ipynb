# %% [markdown]
# # Import

# %%
import os
import pathlib
import sys
from pathlib import __file__

import numpy as np
import tensorflow as tf

sys.path.insert(0, pathlib.Path().absolute().parent.parent.parent.__str__())
sys.path.append(os.path.join(os.path.dirname(__file__), "../../../../src"))

sys.dont_write_bytecode = True

from LSC_recognizer_model.src.coordenates.data.split_dataset import SplitDataset
from utils.holistic.holistic_detector import HolisticDetector
from LSC_recognizer_model.src.utils.sign_dataset import SignDataset

# %%
print("GPU Available: ", tf.config.list_physical_devices('GPU'))
print("CPU Available: ", tf.config.list_physical_devices('CPU'))

# %%
# ----------------- PATHS --------------------------

PATH_PREDICTED_IMG = "../../data/processed/Draw"

PATH_RAW_SIGNS = "../../data/raw/Signs"
PATH_NUMPY_COORDS = "../../data/processed/NumpyParallel"

PATH_CHECKPOINTS_LOAD = "../../models/9-checkpoints-coord-93,3%-zurdo-normalizado"
PATH_CHECKPOINTS_SAVE = "../../models/checkpoints-coord-prueba"

# %% [markdown]
# # 1. Definición data aug para imagenes antes de predicción

# %% [markdown]
# ## 1.1. Transformaciones Individuales
# Se debe crear una lista de tuplas donde el primer valor es la cantidad de imagenes a generar con esta transformación y el segundo valor es la transformación a aplicar.
# Esta transformación duplica el dataset y aplica la transformación a cada imagen, para posteriormente concatenar el dataset original con el dataset transformado. Todo este proceso se hace por cada transformación de la lista.
#
# Ej: Si se tiene un dataset de 10 imagenes y se hace (1, voltear_imagen) se obtendrán 20 imagenes; 10 con las imagenes originales y 10 con las imagenes volteadas. Y se aplica antes de las otras transformaciones.)

# %%
import cv2

def single_aug(image):
    image = cv2.flip(image, 1)
    return image
    
image_single_aug = (1, single_aug)

# %% [markdown]
# ## 1.2. Transformaciones Separadas
# Se debe crear una lista de tuplas donde el primer valor es la cantidad de imagenes a generar con esta transformación y el segundo valor es la transformación a aplicar.
#
# Esta transformación duplica el dataset y aplica la transformación a cada imagen, para posteriormente concatenar el dataset original con el dataset transformado.
# A diferencia de las transformaciones individuales, esta transformación no coge las otras transformaciones que estan en la lista.

# %%
import random

def rotation(image, angle):
    angle = int(random.uniform(-angle, angle))
    h, w = image.shape[:2]
    M = cv2.getRotationMatrix2D((int(w/2), int(h/2)), angle, 1)
    image = cv2.warpAffine(image, M, (w, h))
    return image

def zoom(img, value):
    def fill(img, h, w):
        img = cv2.resize(img, (h, w), cv2.INTER_CUBIC)
        return img

    if value > 1 or value < 0:
        print('Value for zoom should be less than 1 and greater than 0')
        return img

    value = random.uniform(value, 1)
    h, w = img.shape[:2]
    h_taken = int(value*h)
    w_taken = int(value*w)
    h_start = random.randint(0, h-h_taken)
    w_start = random.randint(0, w-w_taken)
    img = img[h_start:h_start+h_taken, w_start:w_start+w_taken, :]
    img = fill(img, h, w)
    return img

image_separated_aug = [
    (3, lambda image: rotation(image, 10)),
    (3, lambda image: zoom(image, 0.5)),
]

# %% [markdown]
# # 2. Capa Split Dataset (Train, Validation y Test)

# %% [markdown]
# ## 2.1. Obtener datasets desde los archivos de las imagenes
#
# Se encarga de generar el dataset con los archos de imagenes directamente.
#
# Si se le pone la variable `save_path_numpy` los results se guardan en la carpeta indicada en formato .npy (coordenadas), es recomendable usar esta variable para que solo se ejecute una vez el proceso de data aug.
#
# Si se le pone la variable `save_path_image_detection_draw` se guardan los results en la carpeta indicada en formato .jpg pintando los landmarks en las imagenes.
#
# Por último están las variables `cant_rotations_per_axie_data_aug`, `x_max_rotation`, `y_max_rotation`, `z_max_rotation` se definen de mejor manera dentro del archivo `src/utils/landmarks/landmarks_info.py` función `data_aug_coords`

# %%
# Comentar esta celda una vez se haya ejecutado por primera vez

#split_dataset = SplitDataset(path_raw_image=PATH_RAW_SIGNS)
#train, test, validation, _ = split_dataset.get_splited_files(
#    save_path_numpy=PATH_NUMPY_COORDS,
#    # save_path_image_detection_draw = PATH_PREDICTED_IMG,
#    image_single_aug=image_single_aug,
#    image_separated_aug=image_separated_aug,
#    cant_rotations_per_axie_data_aug = [2,2,2],
#    x_max_rotation=25,
#    y_max_rotation=40,
#    z_max_rotation=20,
#)

# %% [markdown]
# ## 2.2 Obtener datasets desde los archivos de las coordenadas (.npy)

# %%
split_dataset = SplitDataset(path_numpy=PATH_NUMPY_COORDS)
train, test, validation, _ = split_dataset.get_splited_files()

# %% [markdown]
# # 3. Arreglo datos
# Este proceso es para ajustar correctamente los datos para usar solo las coordenadas de los landmarks que se van a usar.

# %%
X_train, Y_train = split_dataset.get_only_specific_parts_and_fix(
    train, used_parts=["pose", "left_hand", "right_hand"]
)
X_test, Y_test = split_dataset.get_only_specific_parts_and_fix(
    test, used_parts=["pose", "left_hand", "right_hand"]
)
X_validation, Y_validation = split_dataset.get_only_specific_parts_and_fix(
    validation, used_parts=["pose", "left_hand", "right_hand"]
)

# %%
len(train)
# Out:
# 465846

# %%
len(train[0][0][3])
# Out:
# 1404

# %%
len(X_train), len(Y_train)
# Out:
# (465846, 465846)

# %% [markdown]
# # 4. Capa Modelo

# %%
classes = split_dataset.get_classes()
steps_per_epoch = split_dataset.get_recomend_steps_per_epoch()

# %% [markdown]
# ## 4.1 Creación de capa modelo
# Se ingresa el modelo creado y los datos de entrenamiento y validación.

# %%
from LSC_recognizer_model.src.utils.sign_model import SignModel
from LSC_recognizer_model.src.coordenates.models.coordenates_models import INPUT_SHAPE_FIX, get_model_coord_dense_3

modelo = SignModel(
    model = get_model_coord_dense_3(INPUT_SHAPE_FIX, len(classes)),
    dataset_train = None,
    dataset_validation = None,
    X_train = X_train,
    Y_train = Y_train,
    X_validation = X_validation,
    Y_validation = Y_validation
)

# %% [markdown]
# ## 4.2 Definir callbacks

# %%
from keras.callbacks import ModelCheckpoint, TensorBoard

# ============ TensorBoard ============
# To open tensorboard: tensorboard --logdir=. on the folder where the logs are.
log_dir = f"{PATH_CHECKPOINTS_SAVE}/logs"
tb_callback = TensorBoard(log_dir=log_dir)

# ============ Checkpoints ============
checkpoint_filepath = PATH_CHECKPOINTS_SAVE
checkpoint = ModelCheckpoint(filepath=checkpoint_filepath, monitor = 'val_accuracy', verbose=1, save_best_only=True, mode='max')

# ========== Callbacks list ============
callbacks_list = [checkpoint, tb_callback]

# %% [markdown]
# # 4.3 Entrenar modelo

# %%
modelo.train_model(
    epochs = 500,
    optimizer = "Adam",
    loss = "categorical_crossentropy",
    metrics = ["accuracy"],
    callbacks = callbacks_list,
    steps_per_epoch = steps_per_epoch,
    verbose=1,
)
#496 m 47 s
# Out:
# Epoch 1/500
# 18178/18198 [============================>.] - ETA: 0s - loss: 0.8362 - accuracy: 0.7377
# Epoch 1: val_accuracy improved from -inf to 0.84910, saving model to ../../models\checkpoints-coord-prueba
# INFO:tensorflow:Assets written to: ../../models\checkpoints-coord-prueba\assets
# 18198/18198 [==============================] - 33s 2ms/step - loss: 0.8359 - accuracy: 0.7378 - val_loss: 0.4813 - val_accuracy: 0.8491
# Epoch 2/500
# 18193/18198 [============================>.] - ETA: 0s - loss: 0.5939 - accuracy: 0.8122
# Epoch 2: val_accuracy improved from 0.84910 to 0.87120, saving model to ../../models\checkpoints-coord-prueba
# INFO:tensorflow:Assets written to: ../../models\checkpoints-coord-prueba\assets
# 18198/18198 [==============================] - 30s 2ms/step - loss: 0.5939 - accuracy: 0.8122 - val_loss: 0.4152 - val_accuracy: 0.8712
# Epoch 3/500
# 18179/18198 [============================>.] - ETA: 0s - loss: 0.5402 - accuracy: 0.8288
# Epoch 3: val_accuracy improved from 0.87120 to 0.88346, saving model to ../../models\checkpoints-coord-prueba
# INFO:tensorflow:Assets written to: ../../models\checkpoints-coord-prueba\assets
# 18198/18198 [==============================] - 30s 2ms/step - loss: 0.5402 - accuracy: 0.8289 - val_loss: 0.3691 - val_accuracy: 0.8835
# Epoch 4/500
# 18182/18198 [============================>.] - ETA: 0s - loss: 0.5106 - accuracy: 0.8381
# Epoch 4: val_accuracy did not improve from 0.88346
# 18198/18198 [==============================] - 30s 2ms/step - loss: 0.5107 - accuracy: 0.8380 - val_loss: 0.3633 - val_accuracy: 0.8829
# Epoch 5/500
# 18189/18198 [============================>.] - ETA: 0s - loss: 0.4879 - accuracy: 0.8448
# Epoch 5: val_accuracy improved from 0.88346 to 0.88868, saving model to ../../models\checkpoints-coord-prueba
# INFO:tensorflow:Assets written to: ../../models\checkpoints-coord-prueba\assets
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.4879 - accuracy: 0.8448 - val_loss: 0.3498 - val_accuracy: 0.8887
# Epoch 6/500
# 18190/18198 [============================>.] - ETA: 0s - loss: 0.4728 - accuracy: 0.8497
# Epoch 6: val_accuracy improved from 0.88868 to 0.89242, saving model to ../../models\checkpoints-coord-prueba
# INFO:tensorflow:Assets written to: ../../models\checkpoints-coord-prueba\assets
# 18198/18198 [==============================] - 30s 2ms/step - loss: 0.4727 - accuracy: 0.8497 - val_loss: 0.3378 - val_accuracy: 0.8924
# Epoch 7/500
# 18196/18198 [============================>.] - ETA: 0s - loss: 0.4601 - accuracy: 0.8531
# Epoch 7: val_accuracy improved from 0.89242 to 0.89582, saving model to ../../models\checkpoints-coord-prueba
# INFO:tensorflow:Assets written to: ../../models\checkpoints-coord-prueba\assets
# 18198/18198 [==============================] - 30s 2ms/step - loss: 0.4601 - accuracy: 0.8531 - val_loss: 0.3251 - val_accuracy: 0.8958
# Epoch 8/500
# 18175/18198 [============================>.] - ETA: 0s - loss: 0.4490 - accuracy: 0.8565
# Epoch 8: val_accuracy improved from 0.89582 to 0.90442, saving model to ../../models\checkpoints-coord-prueba
# INFO:tensorflow:Assets written to: ../../models\checkpoints-coord-prueba\assets
# 18198/18198 [==============================] - 30s 2ms/step - loss: 0.4489 - accuracy: 0.8566 - val_loss: 0.3046 - val_accuracy: 0.9044
# Epoch 9/500
# 18178/18198 [============================>.] - ETA: 0s - loss: 0.4402 - accuracy: 0.8588
# Epoch 9: val_accuracy did not improve from 0.90442
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.4402 - accuracy: 0.8589 - val_loss: 0.3103 - val_accuracy: 0.9013
# Epoch 10/500
# 18180/18198 [============================>.] - ETA: 0s - loss: 0.4317 - accuracy: 0.8625
# Epoch 10: val_accuracy did not improve from 0.90442
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.4317 - accuracy: 0.8625 - val_loss: 0.3002 - val_accuracy: 0.9043
# Epoch 11/500
# 18174/18198 [============================>.] - ETA: 0s - loss: 0.4251 - accuracy: 0.8640
# Epoch 11: val_accuracy improved from 0.90442 to 0.90909, saving model to ../../models\checkpoints-coord-prueba
# INFO:tensorflow:Assets written to: ../../models\checkpoints-coord-prueba\assets
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.4251 - accuracy: 0.8640 - val_loss: 0.2859 - val_accuracy: 0.9091
# Epoch 12/500
# 18191/18198 [============================>.] - ETA: 0s - loss: 0.4176 - accuracy: 0.8665
# Epoch 12: val_accuracy improved from 0.90909 to 0.90955, saving model to ../../models\checkpoints-coord-prueba
# INFO:tensorflow:Assets written to: ../../models\checkpoints-coord-prueba\assets
# 18198/18198 [==============================] - 30s 2ms/step - loss: 0.4177 - accuracy: 0.8665 - val_loss: 0.2840 - val_accuracy: 0.9096
# Epoch 13/500
# 18168/18198 [============================>.] - ETA: 0s - loss: 0.4123 - accuracy: 0.8679
# Epoch 13: val_accuracy improved from 0.90955 to 0.90964, saving model to ../../models\checkpoints-coord-prueba
# INFO:tensorflow:Assets written to: ../../models\checkpoints-coord-prueba\assets
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.4123 - accuracy: 0.8679 - val_loss: 0.2812 - val_accuracy: 0.9096
# Epoch 14/500
# 18193/18198 [============================>.] - ETA: 0s - loss: 0.4090 - accuracy: 0.8693
# Epoch 14: val_accuracy improved from 0.90964 to 0.91155, saving model to ../../models\checkpoints-coord-prueba
# INFO:tensorflow:Assets written to: ../../models\checkpoints-coord-prueba\assets
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.4090 - accuracy: 0.8693 - val_loss: 0.2763 - val_accuracy: 0.9115
# Epoch 15/500
# 18163/18198 [============================>.] - ETA: 0s - loss: 0.4039 - accuracy: 0.8699
# Epoch 15: val_accuracy improved from 0.91155 to 0.91294, saving model to ../../models\checkpoints-coord-prueba
# INFO:tensorflow:Assets written to: ../../models\checkpoints-coord-prueba\assets
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.4039 - accuracy: 0.8699 - val_loss: 0.2743 - val_accuracy: 0.9129
# Epoch 16/500
# 18188/18198 [============================>.] - ETA: 0s - loss: 0.4003 - accuracy: 0.8721
# Epoch 16: val_accuracy did not improve from 0.91294
# 18198/18198 [==============================] - 30s 2ms/step - loss: 0.4003 - accuracy: 0.8721 - val_loss: 0.2785 - val_accuracy: 0.9115
# Epoch 17/500
# 18177/18198 [============================>.] - ETA: 0s - loss: 0.3998 - accuracy: 0.8719
# Epoch 17: val_accuracy improved from 0.91294 to 0.91488, saving model to ../../models\checkpoints-coord-prueba
# INFO:tensorflow:Assets written to: ../../models\checkpoints-coord-prueba\assets
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.3998 - accuracy: 0.8719 - val_loss: 0.2691 - val_accuracy: 0.9149
# Epoch 18/500
# 18177/18198 [============================>.] - ETA: 0s - loss: 0.3920 - accuracy: 0.8742
# Epoch 18: val_accuracy improved from 0.91488 to 0.91546, saving model to ../../models\checkpoints-coord-prueba
# INFO:tensorflow:Assets written to: ../../models\checkpoints-coord-prueba\assets
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.3920 - accuracy: 0.8742 - val_loss: 0.2708 - val_accuracy: 0.9155
# Epoch 19/500
# 18165/18198 [============================>.] - ETA: 0s - loss: 0.3898 - accuracy: 0.8750
# Epoch 19: val_accuracy improved from 0.91546 to 0.91565, saving model to ../../models\checkpoints-coord-prueba
# INFO:tensorflow:Assets written to: ../../models\checkpoints-coord-prueba\assets
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.3898 - accuracy: 0.8749 - val_loss: 0.2661 - val_accuracy: 0.9156
# Epoch 20/500
# 18170/18198 [============================>.] - ETA: 0s - loss: 0.3866 - accuracy: 0.8763
# Epoch 20: val_accuracy improved from 0.91565 to 0.91762, saving model to ../../models\checkpoints-coord-prueba
# INFO:tensorflow:Assets written to: ../../models\checkpoints-coord-prueba\assets
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.3865 - accuracy: 0.8763 - val_loss: 0.2619 - val_accuracy: 0.9176
# Epoch 21/500
# 18184/18198 [============================>.] - ETA: 0s - loss: 0.3864 - accuracy: 0.8765
# Epoch 21: val_accuracy improved from 0.91762 to 0.92006, saving model to ../../models\checkpoints-coord-prueba
# INFO:tensorflow:Assets written to: ../../models\checkpoints-coord-prueba\assets
# 18198/18198 [==============================] - 31s 2ms/step - loss: 0.3865 - accuracy: 0.8765 - val_loss: 0.2570 - val_accuracy: 0.9201
# Epoch 22/500
# 18178/18198 [============================>.] - ETA: 0s - loss: 0.3813 - accuracy: 0.8785
# Epoch 22: val_accuracy did not improve from 0.92006
# 18198/18198 [==============================] - 34s 2ms/step - loss: 0.3813 - accuracy: 0.8784 - val_loss: 0.2619 - val_accuracy: 0.9175
# Epoch 23/500
# 18181/18198 [============================>.] - ETA: 0s - loss: 0.3778 - accuracy: 0.8792
# Epoch 23: val_accuracy did not improve from 0.92006
# 18198/18198 [==============================] - 32s 2ms/step - loss: 0.3778 - accuracy: 0.8792 - val_loss: 0.2536 - val_accuracy: 0.9181
# Epoch 24/500
# 18180/18198 [============================>.] - ETA: 0s - loss: 0.3755 - accuracy: 0.8794
# Epoch 24: val_accuracy improved from 0.92006 to 0.92223, saving model to ../../models\checkpoints-coord-prueba
# INFO:tensorflow:Assets written to: ../../models\checkpoints-coord-prueba\assets
# 18198/18198 [==============================] - 34s 2ms/step - loss: 0.3756 - accuracy: 0.8794 - val_loss: 0.2450 - val_accuracy: 0.9222
# Epoch 25/500
# 18189/18198 [============================>.] - ETA: 0s - loss: 0.3729 - accuracy: 0.8809
# Epoch 25: val_accuracy did not improve from 0.92223
# 18198/18198 [==============================] - 35s 2ms/step - loss: 0.3729 - accuracy: 0.8808 - val_loss: 0.2525 - val_accuracy: 0.9202
# Epoch 26/500
# 18181/18198 [============================>.] - ETA: 0s - loss: 0.3696 - accuracy: 0.8816
# Epoch 26: val_accuracy did not improve from 0.92223
# 18198/18198 [==============================] - 36s 2ms/step - loss: 0.3696 - accuracy: 0.8816 - val_loss: 0.2497 - val_accuracy: 0.9200
# Epoch 27/500
# 18181/18198 [============================>.] - ETA: 0s - loss: 0.3699 - accuracy: 0.8811
# Epoch 27: val_accuracy did not improve from 0.92223
# 18198/18198 [==============================] - 36s 2ms/step - loss: 0.3699 - accuracy: 0.8811 - val_loss: 0.2455 - val_accuracy: 0.9217
# Epoch 28/500
# 18175/18198 [============================>.] - ETA: 0s - loss: 0.3672 - accuracy: 0.8823
# Epoch 28: val_accuracy did not improve from 0.92223
# 18198/18198 [==============================] - 35s 2ms/step - loss: 0.3672 - accuracy: 0.8823 - val_loss: 0.2559 - val_accuracy: 0.9157
# Epoch 29/500
# 18168/18198 [============================>.] - ETA: 0s - loss: 0.3646 - accuracy: 0.8831
# Epoch 29: val_accuracy improved from 0.92223 to 0.92267, saving model to ../../models\checkpoints-coord-prueba
# INFO:tensorflow:Assets written to: ../../models\checkpoints-coord-prueba\assets
# 18198/18198 [==============================] - 35s 2ms/step - loss: 0.3646 - accuracy: 0.8831 - val_loss: 0.2470 - val_accuracy: 0.9227
# Epoch 30/500
# 18196/18198 [============================>.] - ETA: 0s - loss: 0.3629 - accuracy: 0.8832
# Epoch 30: val_accuracy improved from 0.92267 to 0.92360, saving model to ../../models\checkpoints-coord-prueba
# INFO:tensorflow:Assets written to: ../../models\checkpoints-coord-prueba\assets
# 18198/18198 [==============================] - 35s 2ms/step - loss: 0.3628 - accuracy: 0.8832 - val_loss: 0.2430 - val_accuracy: 0.9236
# Epoch 31/500
# 18175/18198 [============================>.] - ETA: 0s - loss: 0.3620 - accuracy: 0.8839
# Epoch 31: val_accuracy improved from 0.92360 to 0.92396, saving model to ../../models\checkpoints-coord-prueba
# INFO:tensorflow:Assets written to: ../../models\checkpoints-coord-prueba\assets
# 18198/18198 [==============================] - 33s 2ms/step - loss: 0.3619 - accuracy: 0.8839 - val_loss: 0.2420 - val_accuracy: 0.9240
# Epoch 32/500
# 18184/18198 [============================>.] - ETA: 0s - loss: 0.3604 - accuracy: 0.8846
# Epoch 32: val_accuracy did not improve from 0.92396
# 18198/18198 [==============================] - 30s 2ms/step - loss: 0.3605 - accuracy: 0.8846 - val_loss: 0.2428 - val_accuracy: 0.9219
# Epoch 33/500
# 18192/18198 [============================>.] - ETA: 0s - loss: 0.3579 - accuracy: 0.8852
# Epoch 33: val_accuracy did not improve from 0.92396
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.3579 - accuracy: 0.8852 - val_loss: 0.2401 - val_accuracy: 0.9236
# Epoch 34/500
# 18187/18198 [============================>.] - ETA: 0s - loss: 0.3590 - accuracy: 0.8849
# Epoch 34: val_accuracy improved from 0.92396 to 0.92650, saving model to ../../models\checkpoints-coord-prueba
# INFO:tensorflow:Assets written to: ../../models\checkpoints-coord-prueba\assets
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.3589 - accuracy: 0.8849 - val_loss: 0.2307 - val_accuracy: 0.9265
# Epoch 35/500
# 18191/18198 [============================>.] - ETA: 0s - loss: 0.3547 - accuracy: 0.8866
# Epoch 35: val_accuracy did not improve from 0.92650
# 18198/18198 [==============================] - 30s 2ms/step - loss: 0.3548 - accuracy: 0.8866 - val_loss: 0.2343 - val_accuracy: 0.9250
# Epoch 36/500
# 18177/18198 [============================>.] - ETA: 0s - loss: 0.3542 - accuracy: 0.8863
# Epoch 36: val_accuracy did not improve from 0.92650
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.3543 - accuracy: 0.8863 - val_loss: 0.2334 - val_accuracy: 0.9262
# Epoch 37/500
# 18189/18198 [============================>.] - ETA: 0s - loss: 0.3525 - accuracy: 0.8868
# Epoch 37: val_accuracy did not improve from 0.92650
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.3525 - accuracy: 0.8868 - val_loss: 0.2350 - val_accuracy: 0.9232
# Epoch 38/500
# 18189/18198 [============================>.] - ETA: 0s - loss: 0.3505 - accuracy: 0.8878
# Epoch 38: val_accuracy did not improve from 0.92650
# 18198/18198 [==============================] - 30s 2ms/step - loss: 0.3506 - accuracy: 0.8878 - val_loss: 0.2320 - val_accuracy: 0.9248
# Epoch 39/500
# 18197/18198 [============================>.] - ETA: 0s - loss: 0.3497 - accuracy: 0.8873
# Epoch 39: val_accuracy did not improve from 0.92650
# 18198/18198 [==============================] - 30s 2ms/step - loss: 0.3497 - accuracy: 0.8873 - val_loss: 0.2328 - val_accuracy: 0.9252
# Epoch 40/500
# 18189/18198 [============================>.] - ETA: 0s - loss: 0.3473 - accuracy: 0.8887
# Epoch 40: val_accuracy improved from 0.92650 to 0.92817, saving model to ../../models\checkpoints-coord-prueba
# INFO:tensorflow:Assets written to: ../../models\checkpoints-coord-prueba\assets
# 18198/18198 [==============================] - 30s 2ms/step - loss: 0.3473 - accuracy: 0.8887 - val_loss: 0.2243 - val_accuracy: 0.9282
# Epoch 41/500
# 18178/18198 [============================>.] - ETA: 0s - loss: 0.3488 - accuracy: 0.8877
# Epoch 41: val_accuracy did not improve from 0.92817
# 18198/18198 [==============================] - 30s 2ms/step - loss: 0.3488 - accuracy: 0.8878 - val_loss: 0.2329 - val_accuracy: 0.9256
# Epoch 42/500
# 18170/18198 [============================>.] - ETA: 0s - loss: 0.3444 - accuracy: 0.8897
# Epoch 42: val_accuracy did not improve from 0.92817
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.3444 - accuracy: 0.8897 - val_loss: 0.2274 - val_accuracy: 0.9277
# Epoch 43/500
# 18173/18198 [============================>.] - ETA: 0s - loss: 0.3474 - accuracy: 0.8886
# Epoch 43: val_accuracy improved from 0.92817 to 0.92944, saving model to ../../models\checkpoints-coord-prueba
# INFO:tensorflow:Assets written to: ../../models\checkpoints-coord-prueba\assets
# 18198/18198 [==============================] - 30s 2ms/step - loss: 0.3473 - accuracy: 0.8887 - val_loss: 0.2228 - val_accuracy: 0.9294
# Epoch 44/500
# 18175/18198 [============================>.] - ETA: 0s - loss: 0.3441 - accuracy: 0.8894
# Epoch 44: val_accuracy did not improve from 0.92944
# 18198/18198 [==============================] - 30s 2ms/step - loss: 0.3441 - accuracy: 0.8894 - val_loss: 0.2251 - val_accuracy: 0.9276
# Epoch 45/500
# 18195/18198 [============================>.] - ETA: 0s - loss: 0.3423 - accuracy: 0.8903
# Epoch 45: val_accuracy improved from 0.92944 to 0.92975, saving model to ../../models\checkpoints-coord-prueba
# INFO:tensorflow:Assets written to: ../../models\checkpoints-coord-prueba\assets
# 18198/18198 [==============================] - 30s 2ms/step - loss: 0.3423 - accuracy: 0.8903 - val_loss: 0.2254 - val_accuracy: 0.9297
# Epoch 46/500
# 18183/18198 [============================>.] - ETA: 0s - loss: 0.3425 - accuracy: 0.8898
# Epoch 46: val_accuracy did not improve from 0.92975
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.3426 - accuracy: 0.8898 - val_loss: 0.2301 - val_accuracy: 0.9253
# Epoch 47/500
# 18176/18198 [============================>.] - ETA: 0s - loss: 0.3399 - accuracy: 0.8909
# Epoch 47: val_accuracy improved from 0.92975 to 0.93120, saving model to ../../models\checkpoints-coord-prueba
# INFO:tensorflow:Assets written to: ../../models\checkpoints-coord-prueba\assets
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.3399 - accuracy: 0.8909 - val_loss: 0.2169 - val_accuracy: 0.9312
# Epoch 48/500
# 18191/18198 [============================>.] - ETA: 0s - loss: 0.3396 - accuracy: 0.8909
# Epoch 48: val_accuracy did not improve from 0.93120
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.3395 - accuracy: 0.8909 - val_loss: 0.2234 - val_accuracy: 0.9293
# Epoch 49/500
# 18191/18198 [============================>.] - ETA: 0s - loss: 0.3392 - accuracy: 0.8913
# Epoch 49: val_accuracy did not improve from 0.93120
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.3392 - accuracy: 0.8913 - val_loss: 0.2195 - val_accuracy: 0.9308
# Epoch 50/500
# 18172/18198 [============================>.] - ETA: 0s - loss: 0.3381 - accuracy: 0.8916
# Epoch 50: val_accuracy did not improve from 0.93120
# 18198/18198 [==============================] - 30s 2ms/step - loss: 0.3381 - accuracy: 0.8916 - val_loss: 0.2213 - val_accuracy: 0.9287
# Epoch 51/500
# 18182/18198 [============================>.] - ETA: 0s - loss: 0.3359 - accuracy: 0.8920
# Epoch 51: val_accuracy did not improve from 0.93120
# 18198/18198 [==============================] - 30s 2ms/step - loss: 0.3359 - accuracy: 0.8920 - val_loss: 0.2237 - val_accuracy: 0.9270
# Epoch 52/500
# 18167/18198 [============================>.] - ETA: 0s - loss: 0.3379 - accuracy: 0.8915
# Epoch 52: val_accuracy did not improve from 0.93120
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.3380 - accuracy: 0.8914 - val_loss: 0.2257 - val_accuracy: 0.9264
# Epoch 53/500
# 18191/18198 [============================>.] - ETA: 0s - loss: 0.3351 - accuracy: 0.8920
# Epoch 53: val_accuracy improved from 0.93120 to 0.93368, saving model to ../../models\checkpoints-coord-prueba
# INFO:tensorflow:Assets written to: ../../models\checkpoints-coord-prueba\assets
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.3351 - accuracy: 0.8920 - val_loss: 0.2152 - val_accuracy: 0.9337
# Epoch 54/500
# 18187/18198 [============================>.] - ETA: 0s - loss: 0.3346 - accuracy: 0.8924
# Epoch 54: val_accuracy did not improve from 0.93368
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.3346 - accuracy: 0.8925 - val_loss: 0.2212 - val_accuracy: 0.9303
# Epoch 55/500
# 18198/18198 [==============================] - ETA: 0s - loss: 0.3331 - accuracy: 0.8931
# Epoch 55: val_accuracy did not improve from 0.93368
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.3331 - accuracy: 0.8931 - val_loss: 0.2197 - val_accuracy: 0.9289
# Epoch 56/500
# 18180/18198 [============================>.] - ETA: 0s - loss: 0.3331 - accuracy: 0.8930
# Epoch 56: val_accuracy did not improve from 0.93368
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.3332 - accuracy: 0.8930 - val_loss: 0.2220 - val_accuracy: 0.9286
# Epoch 57/500
# 18198/18198 [==============================] - ETA: 0s - loss: 0.3321 - accuracy: 0.8935
# Epoch 57: val_accuracy did not improve from 0.93368
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.3321 - accuracy: 0.8935 - val_loss: 0.2215 - val_accuracy: 0.9289
# Epoch 58/500
# 18175/18198 [============================>.] - ETA: 0s - loss: 0.3302 - accuracy: 0.8941
# Epoch 58: val_accuracy did not improve from 0.93368
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.3302 - accuracy: 0.8941 - val_loss: 0.2139 - val_accuracy: 0.9315
# Epoch 59/500
# 18173/18198 [============================>.] - ETA: 0s - loss: 0.3301 - accuracy: 0.8939
# Epoch 59: val_accuracy did not improve from 0.93368
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.3301 - accuracy: 0.8939 - val_loss: 0.2105 - val_accuracy: 0.9330
# Epoch 60/500
# 18169/18198 [============================>.] - ETA: 0s - loss: 0.3288 - accuracy: 0.8940
# Epoch 60: val_accuracy did not improve from 0.93368
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.3289 - accuracy: 0.8940 - val_loss: 0.2150 - val_accuracy: 0.9309
# Epoch 61/500
# 18169/18198 [============================>.] - ETA: 0s - loss: 0.3285 - accuracy: 0.8941
# Epoch 61: val_accuracy did not improve from 0.93368
# 18198/18198 [==============================] - 30s 2ms/step - loss: 0.3284 - accuracy: 0.8941 - val_loss: 0.2084 - val_accuracy: 0.9330
# Epoch 62/500
# 18185/18198 [============================>.] - ETA: 0s - loss: 0.3286 - accuracy: 0.8943
# Epoch 62: val_accuracy did not improve from 0.93368
# 18198/18198 [==============================] - 28s 2ms/step - loss: 0.3286 - accuracy: 0.8943 - val_loss: 0.2107 - val_accuracy: 0.9332
# Epoch 63/500
# 18193/18198 [============================>.] - ETA: 0s - loss: 0.3279 - accuracy: 0.8947
# Epoch 63: val_accuracy did not improve from 0.93368
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.3279 - accuracy: 0.8947 - val_loss: 0.2113 - val_accuracy: 0.9331
# Epoch 64/500
# 18170/18198 [============================>.] - ETA: 0s - loss: 0.3262 - accuracy: 0.8948
# Epoch 64: val_accuracy did not improve from 0.93368
# 18198/18198 [==============================] - 28s 2ms/step - loss: 0.3262 - accuracy: 0.8948 - val_loss: 0.2158 - val_accuracy: 0.9319
# Epoch 65/500
# 18185/18198 [============================>.] - ETA: 0s - loss: 0.3252 - accuracy: 0.8956
# Epoch 65: val_accuracy did not improve from 0.93368
# 18198/18198 [==============================] - 28s 2ms/step - loss: 0.3252 - accuracy: 0.8956 - val_loss: 0.2122 - val_accuracy: 0.9327
# Epoch 66/500
# 18183/18198 [============================>.] - ETA: 0s - loss: 0.3249 - accuracy: 0.8959
# Epoch 66: val_accuracy did not improve from 0.93368
# 18198/18198 [==============================] - 30s 2ms/step - loss: 0.3249 - accuracy: 0.8959 - val_loss: 0.2128 - val_accuracy: 0.9325
# Epoch 67/500
# 18183/18198 [============================>.] - ETA: 0s - loss: 0.3260 - accuracy: 0.8954
# Epoch 67: val_accuracy improved from 0.93368 to 0.93375, saving model to ../../models\checkpoints-coord-prueba
# INFO:tensorflow:Assets written to: ../../models\checkpoints-coord-prueba\assets
# 18198/18198 [==============================] - 28s 2ms/step - loss: 0.3260 - accuracy: 0.8954 - val_loss: 0.2071 - val_accuracy: 0.9337
# Epoch 68/500
# 18174/18198 [============================>.] - ETA: 0s - loss: 0.3238 - accuracy: 0.8957
# Epoch 68: val_accuracy did not improve from 0.93375
# 18198/18198 [==============================] - 28s 2ms/step - loss: 0.3239 - accuracy: 0.8957 - val_loss: 0.2208 - val_accuracy: 0.9288
# Epoch 69/500
# 18167/18198 [============================>.] - ETA: 0s - loss: 0.3227 - accuracy: 0.8961
# Epoch 69: val_accuracy did not improve from 0.93375
# 18198/18198 [==============================] - 28s 2ms/step - loss: 0.3227 - accuracy: 0.8960 - val_loss: 0.2120 - val_accuracy: 0.9330
# Epoch 70/500
# 18166/18198 [============================>.] - ETA: 0s - loss: 0.3223 - accuracy: 0.8963
# Epoch 70: val_accuracy did not improve from 0.93375
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.3223 - accuracy: 0.8963 - val_loss: 0.2114 - val_accuracy: 0.9322
# Epoch 71/500
# 18190/18198 [============================>.] - ETA: 0s - loss: 0.3214 - accuracy: 0.8966
# Epoch 71: val_accuracy did not improve from 0.93375
# 18198/18198 [==============================] - 28s 2ms/step - loss: 0.3214 - accuracy: 0.8966 - val_loss: 0.2129 - val_accuracy: 0.9323
# Epoch 72/500
# 18175/18198 [============================>.] - ETA: 0s - loss: 0.3219 - accuracy: 0.8967
# Epoch 72: val_accuracy improved from 0.93375 to 0.93555, saving model to ../../models\checkpoints-coord-prueba
# INFO:tensorflow:Assets written to: ../../models\checkpoints-coord-prueba\assets
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.3219 - accuracy: 0.8967 - val_loss: 0.2066 - val_accuracy: 0.9355
# Epoch 73/500
# 18175/18198 [============================>.] - ETA: 0s - loss: 0.3197 - accuracy: 0.8976
# Epoch 73: val_accuracy did not improve from 0.93555
# 18198/18198 [==============================] - 28s 2ms/step - loss: 0.3196 - accuracy: 0.8976 - val_loss: 0.2147 - val_accuracy: 0.9315
# Epoch 74/500
# 18178/18198 [============================>.] - ETA: 0s - loss: 0.3203 - accuracy: 0.8965
# Epoch 74: val_accuracy did not improve from 0.93555
# 18198/18198 [==============================] - 28s 2ms/step - loss: 0.3203 - accuracy: 0.8965 - val_loss: 0.2045 - val_accuracy: 0.9355
# Epoch 75/500
# 18187/18198 [============================>.] - ETA: 0s - loss: 0.3199 - accuracy: 0.8972
# Epoch 75: val_accuracy did not improve from 0.93555
# 18198/18198 [==============================] - 28s 2ms/step - loss: 0.3199 - accuracy: 0.8972 - val_loss: 0.2064 - val_accuracy: 0.9346
# Epoch 76/500
# 18185/18198 [============================>.] - ETA: 0s - loss: 0.3185 - accuracy: 0.8980
# Epoch 76: val_accuracy did not improve from 0.93555
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.3185 - accuracy: 0.8980 - val_loss: 0.2071 - val_accuracy: 0.9341
# Epoch 77/500
# 18191/18198 [============================>.] - ETA: 0s - loss: 0.3180 - accuracy: 0.8983
# Epoch 77: val_accuracy did not improve from 0.93555
# 18198/18198 [==============================] - 28s 2ms/step - loss: 0.3180 - accuracy: 0.8982 - val_loss: 0.2127 - val_accuracy: 0.9322
# Epoch 78/500
# 18192/18198 [============================>.] - ETA: 0s - loss: 0.3177 - accuracy: 0.8984
# Epoch 78: val_accuracy did not improve from 0.93555
# 18198/18198 [==============================] - 28s 2ms/step - loss: 0.3178 - accuracy: 0.8984 - val_loss: 0.2077 - val_accuracy: 0.9334
# Epoch 79/500
# 18164/18198 [============================>.] - ETA: 0s - loss: 0.3167 - accuracy: 0.8981
# Epoch 79: val_accuracy did not improve from 0.93555
# 18198/18198 [==============================] - 28s 2ms/step - loss: 0.3167 - accuracy: 0.8981 - val_loss: 0.2148 - val_accuracy: 0.9290
# Epoch 80/500
# 18196/18198 [============================>.] - ETA: 0s - loss: 0.3174 - accuracy: 0.8977
# Epoch 80: val_accuracy improved from 0.93555 to 0.93704, saving model to ../../models\checkpoints-coord-prueba
# INFO:tensorflow:Assets written to: ../../models\checkpoints-coord-prueba\assets
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.3174 - accuracy: 0.8977 - val_loss: 0.1997 - val_accuracy: 0.9370
# Epoch 81/500
# 18188/18198 [============================>.] - ETA: 0s - loss: 0.3161 - accuracy: 0.8984
# Epoch 81: val_accuracy did not improve from 0.93704
# 18198/18198 [==============================] - 28s 2ms/step - loss: 0.3161 - accuracy: 0.8984 - val_loss: 0.2118 - val_accuracy: 0.9321
# Epoch 82/500
# 18171/18198 [============================>.] - ETA: 0s - loss: 0.3156 - accuracy: 0.8984
# Epoch 82: val_accuracy did not improve from 0.93704
# 18198/18198 [==============================] - 28s 2ms/step - loss: 0.3155 - accuracy: 0.8984 - val_loss: 0.1999 - val_accuracy: 0.9367
# Epoch 83/500
# 18185/18198 [============================>.] - ETA: 0s - loss: 0.3156 - accuracy: 0.8986
# Epoch 83: val_accuracy did not improve from 0.93704
# 18198/18198 [==============================] - 28s 2ms/step - loss: 0.3156 - accuracy: 0.8986 - val_loss: 0.2050 - val_accuracy: 0.9337
# Epoch 84/500
# 18166/18198 [============================>.] - ETA: 0s - loss: 0.3139 - accuracy: 0.8988
# Epoch 84: val_accuracy did not improve from 0.93704
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.3140 - accuracy: 0.8988 - val_loss: 0.2053 - val_accuracy: 0.9348
# Epoch 85/500
# 18191/18198 [============================>.] - ETA: 0s - loss: 0.3148 - accuracy: 0.8992
# Epoch 85: val_accuracy did not improve from 0.93704
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.3148 - accuracy: 0.8992 - val_loss: 0.2027 - val_accuracy: 0.9355
# Epoch 86/500
# 18174/18198 [============================>.] - ETA: 0s - loss: 0.3139 - accuracy: 0.8990
# Epoch 86: val_accuracy did not improve from 0.93704
# 18198/18198 [==============================] - 28s 2ms/step - loss: 0.3139 - accuracy: 0.8990 - val_loss: 0.2040 - val_accuracy: 0.9341
# Epoch 87/500
# 18187/18198 [============================>.] - ETA: 0s - loss: 0.3141 - accuracy: 0.8995
# Epoch 87: val_accuracy did not improve from 0.93704
# 18198/18198 [==============================] - 28s 2ms/step - loss: 0.3141 - accuracy: 0.8995 - val_loss: 0.2017 - val_accuracy: 0.9342
# Epoch 88/500
# 18170/18198 [============================>.] - ETA: 0s - loss: 0.3102 - accuracy: 0.9003
# Epoch 88: val_accuracy improved from 0.93704 to 0.93773, saving model to ../../models\checkpoints-coord-prueba
# INFO:tensorflow:Assets written to: ../../models\checkpoints-coord-prueba\assets
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.3102 - accuracy: 0.9003 - val_loss: 0.1964 - val_accuracy: 0.9377
# Epoch 89/500
# 18173/18198 [============================>.] - ETA: 0s - loss: 0.3133 - accuracy: 0.8990
# Epoch 89: val_accuracy did not improve from 0.93773
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.3134 - accuracy: 0.8989 - val_loss: 0.2051 - val_accuracy: 0.9340
# Epoch 90/500
# 18196/18198 [============================>.] - ETA: 0s - loss: 0.3118 - accuracy: 0.8993
# Epoch 90: val_accuracy did not improve from 0.93773
# 18198/18198 [==============================] - 28s 2ms/step - loss: 0.3118 - accuracy: 0.8993 - val_loss: 0.2063 - val_accuracy: 0.9329
# Epoch 91/500
# 18173/18198 [============================>.] - ETA: 0s - loss: 0.3097 - accuracy: 0.9006
# Epoch 91: val_accuracy did not improve from 0.93773
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.3097 - accuracy: 0.9006 - val_loss: 0.2025 - val_accuracy: 0.9359
# Epoch 92/500
# 18195/18198 [============================>.] - ETA: 0s - loss: 0.3107 - accuracy: 0.8995
# Epoch 92: val_accuracy did not improve from 0.93773
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.3106 - accuracy: 0.8995 - val_loss: 0.2002 - val_accuracy: 0.9357
# Epoch 93/500
# 18195/18198 [============================>.] - ETA: 0s - loss: 0.3104 - accuracy: 0.9002
# Epoch 93: val_accuracy did not improve from 0.93773
# 18198/18198 [==============================] - 28s 2ms/step - loss: 0.3104 - accuracy: 0.9002 - val_loss: 0.1971 - val_accuracy: 0.9370
# Epoch 94/500
# 18171/18198 [============================>.] - ETA: 0s - loss: 0.3085 - accuracy: 0.9008
# Epoch 94: val_accuracy did not improve from 0.93773
# 18198/18198 [==============================] - 28s 2ms/step - loss: 0.3085 - accuracy: 0.9008 - val_loss: 0.2059 - val_accuracy: 0.9343
# Epoch 95/500
# 18169/18198 [============================>.] - ETA: 0s - loss: 0.3082 - accuracy: 0.9008
# Epoch 95: val_accuracy did not improve from 0.93773
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.3082 - accuracy: 0.9008 - val_loss: 0.1983 - val_accuracy: 0.9359
# Epoch 96/500
# 18190/18198 [============================>.] - ETA: 0s - loss: 0.3081 - accuracy: 0.9008
# Epoch 96: val_accuracy improved from 0.93773 to 0.93835, saving model to ../../models\checkpoints-coord-prueba
# INFO:tensorflow:Assets written to: ../../models\checkpoints-coord-prueba\assets
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.3081 - accuracy: 0.9008 - val_loss: 0.1941 - val_accuracy: 0.9383
# Epoch 97/500
# 18180/18198 [============================>.] - ETA: 0s - loss: 0.3086 - accuracy: 0.9009
# Epoch 97: val_accuracy did not improve from 0.93835
# 18198/18198 [==============================] - 28s 2ms/step - loss: 0.3087 - accuracy: 0.9008 - val_loss: 0.2000 - val_accuracy: 0.9369
# Epoch 98/500
# 18184/18198 [============================>.] - ETA: 0s - loss: 0.3091 - accuracy: 0.9005
# Epoch 98: val_accuracy improved from 0.93835 to 0.93962, saving model to ../../models\checkpoints-coord-prueba
# INFO:tensorflow:Assets written to: ../../models\checkpoints-coord-prueba\assets
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.3092 - accuracy: 0.9005 - val_loss: 0.1928 - val_accuracy: 0.9396
# Epoch 99/500
# 18178/18198 [============================>.] - ETA: 0s - loss: 0.3096 - accuracy: 0.9006
# Epoch 99: val_accuracy did not improve from 0.93962
# 18198/18198 [==============================] - 28s 2ms/step - loss: 0.3096 - accuracy: 0.9006 - val_loss: 0.1949 - val_accuracy: 0.9385
# Epoch 100/500
# 18172/18198 [============================>.] - ETA: 0s - loss: 0.3074 - accuracy: 0.9010
# Epoch 100: val_accuracy improved from 0.93962 to 0.93972, saving model to ../../models\checkpoints-coord-prueba
# INFO:tensorflow:Assets written to: ../../models\checkpoints-coord-prueba\assets
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.3074 - accuracy: 0.9010 - val_loss: 0.1931 - val_accuracy: 0.9397
# Epoch 101/500
# 18194/18198 [============================>.] - ETA: 0s - loss: 0.3065 - accuracy: 0.9015
# Epoch 101: val_accuracy improved from 0.93972 to 0.93996, saving model to ../../models\checkpoints-coord-prueba
# INFO:tensorflow:Assets written to: ../../models\checkpoints-coord-prueba\assets
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.3065 - accuracy: 0.9015 - val_loss: 0.1915 - val_accuracy: 0.9400
# Epoch 102/500
# 18170/18198 [============================>.] - ETA: 0s - loss: 0.3064 - accuracy: 0.9016
# Epoch 102: val_accuracy did not improve from 0.93996
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.3063 - accuracy: 0.9016 - val_loss: 0.1927 - val_accuracy: 0.9379
# Epoch 103/500
# 18184/18198 [============================>.] - ETA: 0s - loss: 0.3062 - accuracy: 0.9017
# Epoch 103: val_accuracy did not improve from 0.93996
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.3062 - accuracy: 0.9017 - val_loss: 0.1956 - val_accuracy: 0.9377
# Epoch 104/500
# 18185/18198 [============================>.] - ETA: 0s - loss: 0.3071 - accuracy: 0.9011
# Epoch 104: val_accuracy did not improve from 0.93996
# 18198/18198 [==============================] - 28s 2ms/step - loss: 0.3071 - accuracy: 0.9011 - val_loss: 0.1986 - val_accuracy: 0.9370
# Epoch 105/500
# 18180/18198 [============================>.] - ETA: 0s - loss: 0.3048 - accuracy: 0.9024
# Epoch 105: val_accuracy did not improve from 0.93996
# 18198/18198 [==============================] - 28s 2ms/step - loss: 0.3048 - accuracy: 0.9024 - val_loss: 0.1938 - val_accuracy: 0.9392
# Epoch 106/500
# 18187/18198 [============================>.] - ETA: 0s - loss: 0.3050 - accuracy: 0.9024
# Epoch 106: val_accuracy did not improve from 0.93996
# 18198/18198 [==============================] - 28s 2ms/step - loss: 0.3050 - accuracy: 0.9024 - val_loss: 0.1914 - val_accuracy: 0.9397
# Epoch 107/500
# 18194/18198 [============================>.] - ETA: 0s - loss: 0.3059 - accuracy: 0.9013
# Epoch 107: val_accuracy did not improve from 0.93996
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.3059 - accuracy: 0.9014 - val_loss: 0.1952 - val_accuracy: 0.9374
# Epoch 108/500
# 18168/18198 [============================>.] - ETA: 0s - loss: 0.3055 - accuracy: 0.9017
# Epoch 108: val_accuracy did not improve from 0.93996
# 18198/18198 [==============================] - 28s 2ms/step - loss: 0.3056 - accuracy: 0.9017 - val_loss: 0.1939 - val_accuracy: 0.9381
# Epoch 109/500
# 18195/18198 [============================>.] - ETA: 0s - loss: 0.3054 - accuracy: 0.9019
# Epoch 109: val_accuracy did not improve from 0.93996
# 18198/18198 [==============================] - 28s 2ms/step - loss: 0.3054 - accuracy: 0.9019 - val_loss: 0.1980 - val_accuracy: 0.9366
# Epoch 110/500
# 18179/18198 [============================>.] - ETA: 0s - loss: 0.3028 - accuracy: 0.9027
# Epoch 110: val_accuracy improved from 0.93996 to 0.94185, saving model to ../../models\checkpoints-coord-prueba
# INFO:tensorflow:Assets written to: ../../models\checkpoints-coord-prueba\assets
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.3028 - accuracy: 0.9027 - val_loss: 0.1881 - val_accuracy: 0.9418
# Epoch 111/500
# 18181/18198 [============================>.] - ETA: 0s - loss: 0.3036 - accuracy: 0.9026
# Epoch 111: val_accuracy did not improve from 0.94185
# 18198/18198 [==============================] - 28s 2ms/step - loss: 0.3036 - accuracy: 0.9027 - val_loss: 0.1942 - val_accuracy: 0.9390
# Epoch 112/500
# 18179/18198 [============================>.] - ETA: 0s - loss: 0.3031 - accuracy: 0.9029
# Epoch 112: val_accuracy did not improve from 0.94185
# 18198/18198 [==============================] - 28s 2ms/step - loss: 0.3031 - accuracy: 0.9029 - val_loss: 0.1944 - val_accuracy: 0.9383
# Epoch 113/500
# 18175/18198 [============================>.] - ETA: 0s - loss: 0.3014 - accuracy: 0.9031
# Epoch 113: val_accuracy did not improve from 0.94185
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.3013 - accuracy: 0.9032 - val_loss: 0.1899 - val_accuracy: 0.9414
# Epoch 114/500
# 18190/18198 [============================>.] - ETA: 0s - loss: 0.3028 - accuracy: 0.9029
# Epoch 114: val_accuracy did not improve from 0.94185
# 18198/18198 [==============================] - 28s 2ms/step - loss: 0.3028 - accuracy: 0.9029 - val_loss: 0.1933 - val_accuracy: 0.9388
# Epoch 115/500
# 18172/18198 [============================>.] - ETA: 0s - loss: 0.3023 - accuracy: 0.9031
# Epoch 115: val_accuracy did not improve from 0.94185
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.3022 - accuracy: 0.9031 - val_loss: 0.1913 - val_accuracy: 0.9386
# Epoch 116/500
# 18186/18198 [============================>.] - ETA: 0s - loss: 0.3012 - accuracy: 0.9030
# Epoch 116: val_accuracy did not improve from 0.94185
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.3011 - accuracy: 0.9030 - val_loss: 0.1838 - val_accuracy: 0.9404
# Epoch 117/500
# 18191/18198 [============================>.] - ETA: 0s - loss: 0.3008 - accuracy: 0.9031
# Epoch 117: val_accuracy did not improve from 0.94185
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.3008 - accuracy: 0.9031 - val_loss: 0.1971 - val_accuracy: 0.9374
# Epoch 118/500
# 18192/18198 [============================>.] - ETA: 0s - loss: 0.3005 - accuracy: 0.9036
# Epoch 118: val_accuracy did not improve from 0.94185
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.3005 - accuracy: 0.9036 - val_loss: 0.1909 - val_accuracy: 0.9376
# Epoch 119/500
# 18186/18198 [============================>.] - ETA: 0s - loss: 0.3010 - accuracy: 0.9032
# Epoch 119: val_accuracy improved from 0.94185 to 0.94212, saving model to ../../models\checkpoints-coord-prueba
# INFO:tensorflow:Assets written to: ../../models\checkpoints-coord-prueba\assets
# 18198/18198 [==============================] - 28s 2ms/step - loss: 0.3010 - accuracy: 0.9032 - val_loss: 0.1853 - val_accuracy: 0.9421
# Epoch 120/500
# 18184/18198 [============================>.] - ETA: 0s - loss: 0.3011 - accuracy: 0.9034
# Epoch 120: val_accuracy did not improve from 0.94212
# 18198/18198 [==============================] - 28s 2ms/step - loss: 0.3012 - accuracy: 0.9034 - val_loss: 0.1966 - val_accuracy: 0.9362
# Epoch 121/500
# 18198/18198 [==============================] - ETA: 0s - loss: 0.2994 - accuracy: 0.9040
# Epoch 121: val_accuracy did not improve from 0.94212
# 18198/18198 [==============================] - 28s 2ms/step - loss: 0.2994 - accuracy: 0.9040 - val_loss: 0.1912 - val_accuracy: 0.9395
# Epoch 122/500
# 18166/18198 [============================>.] - ETA: 0s - loss: 0.2991 - accuracy: 0.9038
# Epoch 122: val_accuracy improved from 0.94212 to 0.94250, saving model to ../../models\checkpoints-coord-prueba
# INFO:tensorflow:Assets written to: ../../models\checkpoints-coord-prueba\assets
# 18198/18198 [==============================] - 28s 2ms/step - loss: 0.2991 - accuracy: 0.9038 - val_loss: 0.1813 - val_accuracy: 0.9425
# Epoch 123/500
# 18185/18198 [============================>.] - ETA: 0s - loss: 0.3008 - accuracy: 0.9033
# Epoch 123: val_accuracy did not improve from 0.94250
# 18198/18198 [==============================] - 28s 2ms/step - loss: 0.3008 - accuracy: 0.9033 - val_loss: 0.1875 - val_accuracy: 0.9414
# Epoch 124/500
# 18198/18198 [==============================] - ETA: 0s - loss: 0.2985 - accuracy: 0.9042
# Epoch 124: val_accuracy did not improve from 0.94250
# 18198/18198 [==============================] - 30s 2ms/step - loss: 0.2985 - accuracy: 0.9042 - val_loss: 0.1875 - val_accuracy: 0.9410
# Epoch 125/500
# 18187/18198 [============================>.] - ETA: 0s - loss: 0.2993 - accuracy: 0.9033
# Epoch 125: val_accuracy did not improve from 0.94250
# 18198/18198 [==============================] - 28s 2ms/step - loss: 0.2993 - accuracy: 0.9033 - val_loss: 0.1841 - val_accuracy: 0.9413
# Epoch 126/500
# 18162/18198 [============================>.] - ETA: 0s - loss: 0.2962 - accuracy: 0.9048
# Epoch 126: val_accuracy did not improve from 0.94250
# 18198/18198 [==============================] - 30s 2ms/step - loss: 0.2963 - accuracy: 0.9048 - val_loss: 0.1963 - val_accuracy: 0.9381
# Epoch 127/500
# 18165/18198 [============================>.] - ETA: 0s - loss: 0.2984 - accuracy: 0.9043
# Epoch 127: val_accuracy did not improve from 0.94250
# 18198/18198 [==============================] - 28s 2ms/step - loss: 0.2984 - accuracy: 0.9043 - val_loss: 0.1875 - val_accuracy: 0.9415
# Epoch 128/500
# 18172/18198 [============================>.] - ETA: 0s - loss: 0.2970 - accuracy: 0.9044
# Epoch 128: val_accuracy did not improve from 0.94250
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.2970 - accuracy: 0.9044 - val_loss: 0.1914 - val_accuracy: 0.9381
# Epoch 129/500
# 18168/18198 [============================>.] - ETA: 0s - loss: 0.2963 - accuracy: 0.9046
# Epoch 129: val_accuracy did not improve from 0.94250
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.2963 - accuracy: 0.9046 - val_loss: 0.1858 - val_accuracy: 0.9406
# Epoch 130/500
# 18194/18198 [============================>.] - ETA: 0s - loss: 0.2972 - accuracy: 0.9045
# Epoch 130: val_accuracy did not improve from 0.94250
# 18198/18198 [==============================] - 28s 2ms/step - loss: 0.2972 - accuracy: 0.9045 - val_loss: 0.1852 - val_accuracy: 0.9408
# Epoch 131/500
# 18177/18198 [============================>.] - ETA: 0s - loss: 0.2970 - accuracy: 0.9044
# Epoch 131: val_accuracy did not improve from 0.94250
# 18198/18198 [==============================] - 28s 2ms/step - loss: 0.2970 - accuracy: 0.9044 - val_loss: 0.1845 - val_accuracy: 0.9417
# Epoch 132/500
# 18180/18198 [============================>.] - ETA: 0s - loss: 0.2960 - accuracy: 0.9045
# Epoch 132: val_accuracy did not improve from 0.94250
# 18198/18198 [==============================] - 28s 2ms/step - loss: 0.2961 - accuracy: 0.9045 - val_loss: 0.1856 - val_accuracy: 0.9408
# Epoch 133/500
# 18198/18198 [==============================] - ETA: 0s - loss: 0.2970 - accuracy: 0.9047
# Epoch 133: val_accuracy did not improve from 0.94250
# 18198/18198 [==============================] - 28s 2ms/step - loss: 0.2970 - accuracy: 0.9047 - val_loss: 0.1839 - val_accuracy: 0.9406
# Epoch 134/500
# 18198/18198 [==============================] - ETA: 0s - loss: 0.2946 - accuracy: 0.9053
# Epoch 134: val_accuracy did not improve from 0.94250
# 18198/18198 [==============================] - 28s 2ms/step - loss: 0.2946 - accuracy: 0.9053 - val_loss: 0.1836 - val_accuracy: 0.9415
# Epoch 135/500
# 18173/18198 [============================>.] - ETA: 0s - loss: 0.2960 - accuracy: 0.9049
# Epoch 135: val_accuracy improved from 0.94250 to 0.94284, saving model to ../../models\checkpoints-coord-prueba
# INFO:tensorflow:Assets written to: ../../models\checkpoints-coord-prueba\assets
# 18198/18198 [==============================] - 28s 2ms/step - loss: 0.2959 - accuracy: 0.9049 - val_loss: 0.1808 - val_accuracy: 0.9428
# Epoch 136/500
# 18176/18198 [============================>.] - ETA: 0s - loss: 0.2946 - accuracy: 0.9055
# Epoch 136: val_accuracy did not improve from 0.94284
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.2947 - accuracy: 0.9055 - val_loss: 0.1894 - val_accuracy: 0.9408
# Epoch 137/500
# 18164/18198 [============================>.] - ETA: 0s - loss: 0.2954 - accuracy: 0.9052
# Epoch 137: val_accuracy did not improve from 0.94284
# 18198/18198 [==============================] - 28s 2ms/step - loss: 0.2955 - accuracy: 0.9051 - val_loss: 0.1883 - val_accuracy: 0.9384
# Epoch 138/500
# 18197/18198 [============================>.] - ETA: 0s - loss: 0.2944 - accuracy: 0.9053
# Epoch 138: val_accuracy did not improve from 0.94284
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.2944 - accuracy: 0.9053 - val_loss: 0.1826 - val_accuracy: 0.9425
# Epoch 139/500
# 18168/18198 [============================>.] - ETA: 0s - loss: 0.2943 - accuracy: 0.9056
# Epoch 139: val_accuracy did not improve from 0.94284
# 18198/18198 [==============================] - 30s 2ms/step - loss: 0.2944 - accuracy: 0.9056 - val_loss: 0.1896 - val_accuracy: 0.9395
# Epoch 140/500
# 18183/18198 [============================>.] - ETA: 0s - loss: 0.2949 - accuracy: 0.9056
# Epoch 140: val_accuracy did not improve from 0.94284
# 18198/18198 [==============================] - 28s 2ms/step - loss: 0.2950 - accuracy: 0.9056 - val_loss: 0.1880 - val_accuracy: 0.9400
# Epoch 141/500
# 18161/18198 [============================>.] - ETA: 0s - loss: 0.2935 - accuracy: 0.9060
# Epoch 141: val_accuracy did not improve from 0.94284
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.2934 - accuracy: 0.9060 - val_loss: 0.1852 - val_accuracy: 0.9409
# Epoch 142/500
# 18170/18198 [============================>.] - ETA: 0s - loss: 0.2945 - accuracy: 0.9058
# Epoch 142: val_accuracy did not improve from 0.94284
# 18198/18198 [==============================] - 28s 2ms/step - loss: 0.2945 - accuracy: 0.9058 - val_loss: 0.1860 - val_accuracy: 0.9390
# Epoch 143/500
# 18196/18198 [============================>.] - ETA: 0s - loss: 0.2914 - accuracy: 0.9062
# Epoch 143: val_accuracy improved from 0.94284 to 0.94465, saving model to ../../models\checkpoints-coord-prueba
# INFO:tensorflow:Assets written to: ../../models\checkpoints-coord-prueba\assets
# 18198/18198 [==============================] - 28s 2ms/step - loss: 0.2914 - accuracy: 0.9062 - val_loss: 0.1770 - val_accuracy: 0.9446
# Epoch 144/500
# 18178/18198 [============================>.] - ETA: 0s - loss: 0.2925 - accuracy: 0.9062
# Epoch 144: val_accuracy did not improve from 0.94465
# 18198/18198 [==============================] - 28s 2ms/step - loss: 0.2925 - accuracy: 0.9062 - val_loss: 0.1876 - val_accuracy: 0.9397
# Epoch 145/500
# 18188/18198 [============================>.] - ETA: 0s - loss: 0.2938 - accuracy: 0.9063
# Epoch 145: val_accuracy did not improve from 0.94465
# 18198/18198 [==============================] - 28s 2ms/step - loss: 0.2939 - accuracy: 0.9062 - val_loss: 0.2046 - val_accuracy: 0.9341
# Epoch 146/500
# 18193/18198 [============================>.] - ETA: 0s - loss: 0.2929 - accuracy: 0.9062
# Epoch 146: val_accuracy did not improve from 0.94465
# 18198/18198 [==============================] - 28s 2ms/step - loss: 0.2929 - accuracy: 0.9062 - val_loss: 0.1862 - val_accuracy: 0.9418
# Epoch 147/500
# ...
# 18175/18198 [============================>.] - ETA: 0s - loss: 0.2552 - accuracy: 0.9181
# Epoch 442: val_accuracy did not improve from 0.95340
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.2551 - accuracy: 0.9181 - val_loss: 0.1552 - val_accuracy: 0.9516
# Epoch 443/500
# 18180/18198 [============================>.] - ETA: 0s - loss: 0.2548 - accuracy: 0.9187
# Epoch 443: val_accuracy improved from 0.95340 to 0.95370, saving model to ../../models\checkpoints-coord-prueba
# INFO:tensorflow:Assets written to: ../../models\checkpoints-coord-prueba\assets
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.2548 - accuracy: 0.9187 - val_loss: 0.1483 - val_accuracy: 0.9537
# Epoch 444/500
# 18171/18198 [============================>.] - ETA: 0s - loss: 0.2571 - accuracy: 0.9181
# Epoch 444: val_accuracy did not improve from 0.95370
# 18198/18198 [==============================] - 28s 2ms/step - loss: 0.2570 - accuracy: 0.9182 - val_loss: 0.1522 - val_accuracy: 0.9514
# Epoch 445/500
# 18181/18198 [============================>.] - ETA: 0s - loss: 0.2555 - accuracy: 0.9185
# Epoch 445: val_accuracy did not improve from 0.95370
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.2554 - accuracy: 0.9185 - val_loss: 0.1523 - val_accuracy: 0.9514
# Epoch 446/500
# 18166/18198 [============================>.] - ETA: 0s - loss: 0.2559 - accuracy: 0.9187
# Epoch 446: val_accuracy did not improve from 0.95370
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.2559 - accuracy: 0.9186 - val_loss: 0.1586 - val_accuracy: 0.9498
# Epoch 447/500
# 18185/18198 [============================>.] - ETA: 0s - loss: 0.2540 - accuracy: 0.9188
# Epoch 447: val_accuracy did not improve from 0.95370
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.2539 - accuracy: 0.9188 - val_loss: 0.1556 - val_accuracy: 0.9501
# Epoch 448/500
# 18191/18198 [============================>.] - ETA: 0s - loss: 0.2563 - accuracy: 0.9184
# Epoch 448: val_accuracy did not improve from 0.95370
# 18198/18198 [==============================] - 28s 2ms/step - loss: 0.2563 - accuracy: 0.9184 - val_loss: 0.1528 - val_accuracy: 0.9509
# Epoch 449/500
# 18192/18198 [============================>.] - ETA: 0s - loss: 0.2555 - accuracy: 0.9184
# Epoch 449: val_accuracy did not improve from 0.95370
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.2555 - accuracy: 0.9184 - val_loss: 0.1524 - val_accuracy: 0.9520
# Epoch 450/500
# 18192/18198 [============================>.] - ETA: 0s - loss: 0.2552 - accuracy: 0.9182
# Epoch 450: val_accuracy did not improve from 0.95370
# 18198/18198 [==============================] - 30s 2ms/step - loss: 0.2553 - accuracy: 0.9182 - val_loss: 0.1545 - val_accuracy: 0.9497
# Epoch 451/500
# 18182/18198 [============================>.] - ETA: 0s - loss: 0.2543 - accuracy: 0.9185
# Epoch 451: val_accuracy did not improve from 0.95370
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.2543 - accuracy: 0.9185 - val_loss: 0.1505 - val_accuracy: 0.9525
# Epoch 452/500
# 18181/18198 [============================>.] - ETA: 0s - loss: 0.2558 - accuracy: 0.9186
# Epoch 452: val_accuracy improved from 0.95370 to 0.95409, saving model to ../../models\checkpoints-coord-prueba
# INFO:tensorflow:Assets written to: ../../models\checkpoints-coord-prueba\assets
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.2558 - accuracy: 0.9186 - val_loss: 0.1464 - val_accuracy: 0.9541
# Epoch 453/500
# 18183/18198 [============================>.] - ETA: 0s - loss: 0.2536 - accuracy: 0.9191
# Epoch 453: val_accuracy did not improve from 0.95409
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.2536 - accuracy: 0.9191 - val_loss: 0.1535 - val_accuracy: 0.9502
# Epoch 454/500
# 18172/18198 [============================>.] - ETA: 0s - loss: 0.2553 - accuracy: 0.9185
# Epoch 454: val_accuracy did not improve from 0.95409
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.2553 - accuracy: 0.9185 - val_loss: 0.1481 - val_accuracy: 0.9530
# Epoch 455/500
# 18167/18198 [============================>.] - ETA: 0s - loss: 0.2543 - accuracy: 0.9188
# Epoch 455: val_accuracy did not improve from 0.95409
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.2544 - accuracy: 0.9188 - val_loss: 0.1557 - val_accuracy: 0.9514
# Epoch 456/500
# 18171/18198 [============================>.] - ETA: 0s - loss: 0.2537 - accuracy: 0.9187
# Epoch 456: val_accuracy did not improve from 0.95409
# 18198/18198 [==============================] - 28s 2ms/step - loss: 0.2537 - accuracy: 0.9187 - val_loss: 0.1499 - val_accuracy: 0.9529
# Epoch 457/500
# 18185/18198 [============================>.] - ETA: 0s - loss: 0.2535 - accuracy: 0.9191
# Epoch 457: val_accuracy did not improve from 0.95409
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.2535 - accuracy: 0.9191 - val_loss: 0.1500 - val_accuracy: 0.9531
# Epoch 458/500
# 18173/18198 [============================>.] - ETA: 0s - loss: 0.2551 - accuracy: 0.9188
# Epoch 458: val_accuracy did not improve from 0.95409
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.2551 - accuracy: 0.9188 - val_loss: 0.1644 - val_accuracy: 0.9461
# Epoch 459/500
# 18169/18198 [============================>.] - ETA: 0s - loss: 0.2546 - accuracy: 0.9187
# Epoch 459: val_accuracy did not improve from 0.95409
# 18198/18198 [==============================] - 28s 2ms/step - loss: 0.2546 - accuracy: 0.9187 - val_loss: 0.1540 - val_accuracy: 0.9515
# Epoch 460/500
# 18186/18198 [============================>.] - ETA: 0s - loss: 0.2564 - accuracy: 0.9184
# Epoch 460: val_accuracy did not improve from 0.95409
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.2564 - accuracy: 0.9184 - val_loss: 0.1587 - val_accuracy: 0.9489
# Epoch 461/500
# 18174/18198 [============================>.] - ETA: 0s - loss: 0.2548 - accuracy: 0.9188
# Epoch 461: val_accuracy did not improve from 0.95409
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.2547 - accuracy: 0.9188 - val_loss: 0.1555 - val_accuracy: 0.9500
# Epoch 462/500
# 18182/18198 [============================>.] - ETA: 0s - loss: 0.2522 - accuracy: 0.9193
# Epoch 462: val_accuracy did not improve from 0.95409
# 18198/18198 [==============================] - 31s 2ms/step - loss: 0.2522 - accuracy: 0.9193 - val_loss: 0.1476 - val_accuracy: 0.9532
# Epoch 463/500
# 18167/18198 [============================>.] - ETA: 0s - loss: 0.2525 - accuracy: 0.9194
# Epoch 463: val_accuracy did not improve from 0.95409
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.2526 - accuracy: 0.9194 - val_loss: 0.1515 - val_accuracy: 0.9525
# Epoch 464/500
# 18175/18198 [============================>.] - ETA: 0s - loss: 0.2539 - accuracy: 0.9191
# Epoch 464: val_accuracy did not improve from 0.95409
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.2539 - accuracy: 0.9191 - val_loss: 0.1492 - val_accuracy: 0.9532
# Epoch 465/500
# 18183/18198 [============================>.] - ETA: 0s - loss: 0.2540 - accuracy: 0.9188
# Epoch 465: val_accuracy did not improve from 0.95409
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.2540 - accuracy: 0.9188 - val_loss: 0.1503 - val_accuracy: 0.9521
# Epoch 466/500
# 18167/18198 [============================>.] - ETA: 0s - loss: 0.2543 - accuracy: 0.9189
# Epoch 466: val_accuracy did not improve from 0.95409
# 18198/18198 [==============================] - 28s 2ms/step - loss: 0.2543 - accuracy: 0.9189 - val_loss: 0.1588 - val_accuracy: 0.9488
# Epoch 467/500
# 18172/18198 [============================>.] - ETA: 0s - loss: 0.2533 - accuracy: 0.9194
# Epoch 467: val_accuracy did not improve from 0.95409
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.2533 - accuracy: 0.9194 - val_loss: 0.1463 - val_accuracy: 0.9536
# Epoch 468/500
# 18171/18198 [============================>.] - ETA: 0s - loss: 0.2531 - accuracy: 0.9190
# Epoch 468: val_accuracy did not improve from 0.95409
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.2530 - accuracy: 0.9191 - val_loss: 0.1475 - val_accuracy: 0.9531
# Epoch 469/500
# 18179/18198 [============================>.] - ETA: 0s - loss: 0.2552 - accuracy: 0.9191
# Epoch 469: val_accuracy did not improve from 0.95409
# 18198/18198 [==============================] - 28s 2ms/step - loss: 0.2552 - accuracy: 0.9191 - val_loss: 0.1555 - val_accuracy: 0.9498
# Epoch 470/500
# 18198/18198 [==============================] - ETA: 0s - loss: 0.2540 - accuracy: 0.9190
# Epoch 470: val_accuracy did not improve from 0.95409
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.2540 - accuracy: 0.9190 - val_loss: 0.1523 - val_accuracy: 0.9521
# Epoch 471/500
# 18188/18198 [============================>.] - ETA: 0s - loss: 0.2556 - accuracy: 0.9189
# Epoch 471: val_accuracy did not improve from 0.95409
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.2556 - accuracy: 0.9189 - val_loss: 0.1524 - val_accuracy: 0.9514
# Epoch 472/500
# 18188/18198 [============================>.] - ETA: 0s - loss: 0.2533 - accuracy: 0.9191
# Epoch 472: val_accuracy did not improve from 0.95409
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.2533 - accuracy: 0.9191 - val_loss: 0.1560 - val_accuracy: 0.9504
# Epoch 473/500
# 18185/18198 [============================>.] - ETA: 0s - loss: 0.2528 - accuracy: 0.9191
# Epoch 473: val_accuracy did not improve from 0.95409
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.2527 - accuracy: 0.9191 - val_loss: 0.1481 - val_accuracy: 0.9539
# Epoch 474/500
# 18195/18198 [============================>.] - ETA: 0s - loss: 0.2539 - accuracy: 0.9186
# Epoch 474: val_accuracy improved from 0.95409 to 0.95452, saving model to ../../models\checkpoints-coord-prueba
# INFO:tensorflow:Assets written to: ../../models\checkpoints-coord-prueba\assets
# 18198/18198 [==============================] - 30s 2ms/step - loss: 0.2539 - accuracy: 0.9186 - val_loss: 0.1465 - val_accuracy: 0.9545
# Epoch 475/500
# 18195/18198 [============================>.] - ETA: 0s - loss: 0.2548 - accuracy: 0.9190
# Epoch 475: val_accuracy did not improve from 0.95452
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.2548 - accuracy: 0.9190 - val_loss: 0.1481 - val_accuracy: 0.9543
# Epoch 476/500
# 18187/18198 [============================>.] - ETA: 0s - loss: 0.2517 - accuracy: 0.9193
# Epoch 476: val_accuracy did not improve from 0.95452
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.2517 - accuracy: 0.9192 - val_loss: 0.1484 - val_accuracy: 0.9533
# Epoch 477/500
# 18181/18198 [============================>.] - ETA: 0s - loss: 0.2531 - accuracy: 0.9194
# Epoch 477: val_accuracy did not improve from 0.95452
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.2531 - accuracy: 0.9194 - val_loss: 0.1559 - val_accuracy: 0.9497
# Epoch 478/500
# 18182/18198 [============================>.] - ETA: 0s - loss: 0.2528 - accuracy: 0.9192
# Epoch 478: val_accuracy did not improve from 0.95452
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.2528 - accuracy: 0.9192 - val_loss: 0.1587 - val_accuracy: 0.9480
# Epoch 479/500
# 18185/18198 [============================>.] - ETA: 0s - loss: 0.2541 - accuracy: 0.9191
# Epoch 479: val_accuracy did not improve from 0.95452
# 18198/18198 [==============================] - 28s 2ms/step - loss: 0.2541 - accuracy: 0.9191 - val_loss: 0.1630 - val_accuracy: 0.9487
# Epoch 480/500
# 18168/18198 [============================>.] - ETA: 0s - loss: 0.2536 - accuracy: 0.9188
# Epoch 480: val_accuracy did not improve from 0.95452
# 18198/18198 [==============================] - 28s 2ms/step - loss: 0.2536 - accuracy: 0.9188 - val_loss: 0.1560 - val_accuracy: 0.9498
# Epoch 481/500
# 18173/18198 [============================>.] - ETA: 0s - loss: 0.2522 - accuracy: 0.9196
# Epoch 481: val_accuracy did not improve from 0.95452
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.2522 - accuracy: 0.9196 - val_loss: 0.1509 - val_accuracy: 0.9519
# Epoch 482/500
# 18163/18198 [============================>.] - ETA: 0s - loss: 0.2514 - accuracy: 0.9193
# Epoch 482: val_accuracy did not improve from 0.95452
# 18198/18198 [==============================] - 28s 2ms/step - loss: 0.2515 - accuracy: 0.9192 - val_loss: 0.1489 - val_accuracy: 0.9542
# Epoch 483/500
# 18196/18198 [============================>.] - ETA: 0s - loss: 0.2533 - accuracy: 0.9192
# Epoch 483: val_accuracy did not improve from 0.95452
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.2533 - accuracy: 0.9192 - val_loss: 0.1557 - val_accuracy: 0.9504
# Epoch 484/500
# 18175/18198 [============================>.] - ETA: 0s - loss: 0.2514 - accuracy: 0.9200
# Epoch 484: val_accuracy did not improve from 0.95452
# 18198/18198 [==============================] - 28s 2ms/step - loss: 0.2514 - accuracy: 0.9200 - val_loss: 0.1481 - val_accuracy: 0.9528
# Epoch 485/500
# 18186/18198 [============================>.] - ETA: 0s - loss: 0.2554 - accuracy: 0.9187
# Epoch 485: val_accuracy did not improve from 0.95452
# 18198/18198 [==============================] - 30s 2ms/step - loss: 0.2553 - accuracy: 0.9187 - val_loss: 0.1594 - val_accuracy: 0.9494
# Epoch 486/500
# 18168/18198 [============================>.] - ETA: 0s - loss: 0.2528 - accuracy: 0.9193
# Epoch 486: val_accuracy did not improve from 0.95452
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.2527 - accuracy: 0.9193 - val_loss: 0.1478 - val_accuracy: 0.9526
# Epoch 487/500
# 18192/18198 [============================>.] - ETA: 0s - loss: 0.2503 - accuracy: 0.9201
# Epoch 487: val_accuracy did not improve from 0.95452
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.2503 - accuracy: 0.9201 - val_loss: 0.1481 - val_accuracy: 0.9520
# Epoch 488/500
# 18178/18198 [============================>.] - ETA: 0s - loss: 0.2534 - accuracy: 0.9190
# Epoch 488: val_accuracy did not improve from 0.95452
# 18198/18198 [==============================] - 30s 2ms/step - loss: 0.2534 - accuracy: 0.9190 - val_loss: 0.1514 - val_accuracy: 0.9520
# Epoch 489/500
# 18198/18198 [==============================] - ETA: 0s - loss: 0.2528 - accuracy: 0.9192
# Epoch 489: val_accuracy did not improve from 0.95452
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.2528 - accuracy: 0.9192 - val_loss: 0.1475 - val_accuracy: 0.9533
# Epoch 490/500
# 18171/18198 [============================>.] - ETA: 0s - loss: 0.2508 - accuracy: 0.9198
# Epoch 490: val_accuracy improved from 0.95452 to 0.95500, saving model to ../../models\checkpoints-coord-prueba
# INFO:tensorflow:Assets written to: ../../models\checkpoints-coord-prueba\assets
# 18198/18198 [==============================] - 31s 2ms/step - loss: 0.2508 - accuracy: 0.9198 - val_loss: 0.1443 - val_accuracy: 0.9550
# Epoch 491/500
# 18196/18198 [============================>.] - ETA: 0s - loss: 0.2542 - accuracy: 0.9192
# Epoch 491: val_accuracy did not improve from 0.95500
# 18198/18198 [==============================] - 30s 2ms/step - loss: 0.2542 - accuracy: 0.9192 - val_loss: 0.1478 - val_accuracy: 0.9535
# Epoch 492/500
# 18175/18198 [============================>.] - ETA: 0s - loss: 0.2528 - accuracy: 0.9191
# Epoch 492: val_accuracy did not improve from 0.95500
# 18198/18198 [==============================] - 29s 2ms/step - loss: 0.2529 - accuracy: 0.9190 - val_loss: 0.1504 - val_accuracy: 0.9514
# Epoch 493/500
#  5583/18198 [========>.....................] - ETA: 19s - loss: 0.2525 - accuracy: 0.9183WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 9099000 batches). You may need to use the repeat() function when building your dataset.
#
# Epoch 493: val_accuracy did not improve from 0.95500
# 18198/18198 [==============================] - 11s 605us/step - loss: 0.2526 - accuracy: 0.9183 - val_loss: 0.1478 - val_accuracy: 0.9533

# %% [markdown]
# ## 4.4 Guardar results del entrenamiento

# %%
plot_acc_los, plot_confusion_matrix = modelo.save_plot_results(
    X_test = X_test,
    Y_test = Y_test,
    path_to_save = PATH_CHECKPOINTS_SAVE
)
# Out:
# 1820/1820 [==============================] - 1s 618us/step

# %% [markdown]
# ## 4.4 Visualizar results del entrenamiento

# %%
#plot_acc_los = modelo.get_plot_acc_loss()
#plot_acc_los.plot()

# %%
#plot_confusion_matrix, score = modelo.get_plot_confusion_matrix(X_test, Y_test)
#plot_confusion_matrix.plot()

# %% [markdown]
# # 5. Cargar Pesos de modelo
# Esto se puede usar cuando se quiere cargar los pesos de un modelo ya entrenado sin tener que volver a entrenar el modelo.

# %%
# Path al modelo recien entrenado
#modelo.load_model_weights(PATH_CHECKPOINTS_SAVE)

# Path al modelo a cargar (por lo general el mejor)
modelo.load_model_weights(PATH_CHECKPOINTS_LOAD)

# %% [markdown]
# # 5. Prueba reales de los resultados

# %%
import time

import cv2
from utils.holistic.holistic_detector import HolisticDetector

ptiempo = 0

# Crearemos el objeto
holistic = HolisticDetector()

# Leemos la cámara web
cap = cv2.VideoCapture(0)

while cap.isOpened():
    
    # Leemos el fotograma de la cámara
    success, image = cap.read()

    if not success:
        break

    # Una vez que obtengamos la imagen la enviaremos
    results = holistic.detect_holistic(image)
    
    # Dibujamos la predicción en el fotograma
    image = holistic.draw_prediction(image, results)

    # Predicción
    x = holistic.get_coordenates(results, used_parts=["pose", "right_hand", "left_hand"])
    try:
        res = modelo.get_prediction(x, classes)
    except Exception as e:
        print("Error: ", e)

    # Viz probabilities
    image = holistic.probability_visualizer(res, classes, image)

    # Mostramos los fps
    ctiempo = time.time()
    fps = 1 / (ctiempo - ptiempo)
    ptiempo = ctiempo
    cv2.putText(image, str(int(fps)), (image.shape[1]-100, 70), cv2.FONT_HERSHEY_PLAIN, 3, (255, 0, 255), 3)

    # Mostramos todo el fotograma modificado
    cv2.imshow("holistic", image)

    # Break gracefully
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break

    
cap.release()
cv2.destroyAllWindows()
